# %%
# Dependencies
import pandas as pd
import requests

# API Key
from config import apikey

# %%
# Read the data
cont_data_df = pd.read_csv("./Resources/2021_Contributions.csv", low_memory=False)
cont_data_df.head()
# Out:
#    ELECTION OFFICECD RECIPID CANCLASS                 RECIPNAME COMMITTEE  \
# 0      2021        1    2563        P        Tirschwell, Sara A         H
# 1      2021       55    2345        P       Camarena, Rodrigo G         H
# 2      2021       55    2414        P              Low, Jenny L         H
# 3      2021       55     283        P          Gennaro, James F         M
# 4      2021       55    2454        P  Boghosian Murphy, Leslie         H
#
#   FILING SCHEDULE  PAGENO  SEQUENCENO  ... INTEMPSTNM INTEMPCITY INTEMPST  \
# 0      7      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 1      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 2      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 3      7      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 4      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
#
#   INTOCCUPA PURPOSECD  EXEMPTCD  ADJTYPECD  RR_IND SEG_IND INT_C_CODE
# ...

# %%
# Filter for data containing relevant columns
cont_data_df = cont_data_df.filter(['OFFICECD', 'RECIPID', 'CANCLASS', 'RECIPNAME', 'COMMITTEE', 'FILING', 'SCHEDULE', 'REFNO', 'DATE', 'NAME', 'C_CODE', 'BOROUGHCD', 'CITY', 'STATE', 'ZIP', 'AMNT', 'MATCHAMNT', 'PREVAMNT', 'PAY_METHOD', 'RR_IND', 'SEG_IND'], axis=1)
cont_data_df
# Out:
#        OFFICECD RECIPID CANCLASS                 RECIPNAME COMMITTEE FILING  \
# 0             1    2563        P        Tirschwell, Sara A         H      7
# 1            55    2345        P       Camarena, Rodrigo G         H      6
# 2            55    2414        P              Low, Jenny L         H      6
# 3            55     283        P          Gennaro, James F         M      7
# 4            55    2454        P  Boghosian Murphy, Leslie         H      6
# ...         ...     ...      ...                       ...       ...    ...
# 420160       11    2393        P             Wiley, Maya D         H      7
# 420161       33    1559        P          Johnson, Corey D         L      3
# 420162       11    2618        P             Sliwa, Curtis         H     10
# 420163       11    1545        P             Adams, Eric L         L      1
# 420164       11    1545        P             Adams, Eric L         L      4
#
# ...

# %%
# Filter out refunded contributions (negative contributions under the AMNT column)
cont_data_df.drop(cont_data_df[cont_data_df['AMNT'] <= 0].index, inplace=True)
cont_data_df
# Out:
#        OFFICECD RECIPID CANCLASS                 RECIPNAME COMMITTEE FILING  \
# 0             1    2563        P        Tirschwell, Sara A         H      7
# 1            55    2345        P       Camarena, Rodrigo G         H      6
# 2            55    2414        P              Low, Jenny L         H      6
# 3            55     283        P          Gennaro, James F         M      7
# 4            55    2454        P  Boghosian Murphy, Leslie         H      6
# ...         ...     ...      ...                       ...       ...    ...
# 420159       11    2546        P              Yang, Andrew         H      9
# 420160       11    2393        P             Wiley, Maya D         H      7
# 420161       33    1559        P          Johnson, Corey D         L      3
# 420162       11    2618        P             Sliwa, Curtis         H     10
# 420163       11    1545        P             Adams, Eric L         L      1
#
# ...
