# %%
# Dependencies
import pandas as pd
import requests

# API Key
from config import apikey

# %%
cont_data_df = pd.read_csv("./Resources/2021_Contributions.csv", low_memory=False)
cont_data_df.head()
# Out:
#    ELECTION OFFICECD RECIPID CANCLASS                 RECIPNAME COMMITTEE  \
# 0      2021        1    2563        P        Tirschwell, Sara A         H
# 1      2021       55    2345        P       Camarena, Rodrigo G         H
# 2      2021       55    2414        P              Low, Jenny L         H
# 3      2021       55     283        P          Gennaro, James F         M
# 4      2021       55    2454        P  Boghosian Murphy, Leslie         H
#
#   FILING SCHEDULE  PAGENO  SEQUENCENO  ... INTEMPSTNM INTEMPCITY INTEMPST  \
# 0      7      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 1      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 2      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 3      7      ABC     NaN         NaN  ...        NaN        NaN      NaN
# 4      6      ABC     NaN         NaN  ...        NaN        NaN      NaN
#
#   INTOCCUPA PURPOSECD  EXEMPTCD  ADJTYPECD  RR_IND SEG_IND INT_C_CODE
# ...

# %%
cont_data_df = cont_data_df.dataset(['OFFICECD', 'RECIPID', 'CANCLASS', 'RECIPNAME', 'COMMITTEE', 'FILING', 'SCHEDULE', 'REFNO', 'DATE', 'REFUNDDATE', 'NAME', 'C_CODE', 'BOROUGHCD', 'CITY', 'STATE', 'ZIP', 'AMNT', 'MATCHAMNT', 'PREVAMNT', 'PAY_METHOD', 'RR_IND', 'SEG_IND'])
#cont_data_df = cont_data_df.dropna
cont_data_df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-37-c59c9bf99e20> in <module>
# ----> 1 cont_data_df = cont_data_df.dataset(['OFFICECD', 'RECIPID', 'CANCLASS', 'RECIPNAME', 'COMMITTEE', 'FILING', 'SCHEDULE', 'REFNO', 'DATE', 'REFUNDDATE', 'NAME', 'C_CODE', 'BOROUGHCD', 'CITY', 'STATE', 'ZIP', 'AMNT', 'MATCHAMNT', 'PREVAMNT', 'PAY_METHOD', 'RR_IND', 'SEG_IND'])
#       2 #cont_data_df = cont_data_df.dropna
#       3 cont_data_df
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# ...
