# %%
# Dependencies
import numpy as np
import pandas as pd
import requests

# %%
# Read the data
cont_data_df = pd.read_csv("./Resources/Clean_Committee_2017.csv", low_memory=False)
cont_data_df.head()
# Out:
#    Unnamed: 0  Election  CandidateID    CandidateName        Date  \
# 0           0      2017          326  de Blasio, Bill  2017-09-09
# 1           1      2017          326  de Blasio, Bill  2016-07-08
# 2           2      2017          326  de Blasio, Bill  2017-01-11
# 3           3      2017          326  de Blasio, Bill  2017-09-11
# 4           4      2017          326  de Blasio, Bill  2017-08-07
#
#                              Name             ContributerType BoroughName  \
# 0  1199/SEIU NYS Pol. Action Fund  Political Action Committee   Manhattan
# 1                 32BJ United ADF  Political Action Committee   Manhattan
# 2                 32BJ United ADF  Political Action Committee   Manhattan
# 3          ACEC New York City PAC  Political Action Committee   Manhattan
# 4              AFSCME DC 1707 PAC  Political Action Committee   Manhattan
#
#        City State  ZipCode ContributionState  Amount  MatchAmt  PrevAmt  \
# ...

# %%
# Drop unnecessary columns
cont_data_df = cont_data_df.drop(['CandidateID', 'Date', 'ContributionState', 'ContributerType', 'PayMethod'], axis=1)
cont_data_df
# Out:
#      Unnamed: 0  Election    CandidateName                            Name  \
# 0             0      2017  de Blasio, Bill  1199/SEIU NYS Pol. Action Fund
# 1             1      2017  de Blasio, Bill                 32BJ United ADF
# 2             2      2017  de Blasio, Bill                 32BJ United ADF
# 3             3      2017  de Blasio, Bill          ACEC New York City PAC
# 4             4      2017  de Blasio, Bill              AFSCME DC 1707 PAC
# ..          ...       ...              ...                             ...
# 211         211      2017  de Blasio, Bill  United Food and Commercial Wor
# 212         212      2017  de Blasio, Bill  United Food and Commercial Wor
# 213         213      2017  de Blasio, Bill          USW D-4 NY, NJ, DE, ME
# 214         214      2017  de Blasio, Bill                 Van Bramer 2017
# 215         215      2017  de Blasio, Bill  Voice of Teachers for Educatio
#
# ...

# %%
# Drop all blank columns
cont_data_df = cont_data_df.dropna()
cont_data_df
# Out:
#      Unnamed: 0  Election    CandidateName                            Name  \
# 0             0      2017  de Blasio, Bill  1199/SEIU NYS Pol. Action Fund
# 1             1      2017  de Blasio, Bill                 32BJ United ADF
# 2             2      2017  de Blasio, Bill                 32BJ United ADF
# 3             3      2017  de Blasio, Bill          ACEC New York City PAC
# 4             4      2017  de Blasio, Bill              AFSCME DC 1707 PAC
# ..          ...       ...              ...                             ...
# 211         211      2017  de Blasio, Bill  United Food and Commercial Wor
# 212         212      2017  de Blasio, Bill  United Food and Commercial Wor
# 213         213      2017  de Blasio, Bill          USW D-4 NY, NJ, DE, ME
# 214         214      2017  de Blasio, Bill                 Van Bramer 2017
# 215         215      2017  de Blasio, Bill  Voice of Teachers for Educatio
#
# ...

# %%
# Regularize numerical columns
cont_data_df['ZipCode'] = cont_data_df['ZipCode'].astype(int)
cont_data_df['Amount'] = cont_data_df['Amount'].astype(int)
cont_data_df['PrevAmt'] = cont_data_df['PrevAmt'].astype(int)
cont_data_df['TotalAmount'] = cont_data_df['TotalAmount'].astype(int)
cont_data_df
# Out:
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# ...

# %%
# Converting dollar amounts according to inflation (figures derived from https://www.usinflationcalculator.com/)
cont_data_df['ElectionTemp'] = cont_data_df['Election']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2001, 'AdjustedAmount'] = cont_data_df['Amount']*1.55
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2005, 'AdjustedAmount'] = cont_data_df['Amount']*1.40
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2009, 'AdjustedAmount'] = cont_data_df['Amount']*1.28
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2013, 'AdjustedAmount'] = cont_data_df['Amount']*1.17
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2017, 'AdjustedAmount'] = cont_data_df['Amount']*1.11
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2021, 'AdjustedAmount'] = cont_data_df['Amount']*1.00

cont_data_df['ElectionTemp'] = cont_data_df['Election']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2001, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.55
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2005, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.40
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2009, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.28
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2013, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.17
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2017, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.11
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2021, 'AdjustedMatchAmt'] = cont_data_df['MatchAmt']*1.00

cont_data_df['ElectionTemp'] = cont_data_df['Election']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2001, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.55
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2005, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.40
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2009, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.28
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2013, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.17
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2017, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.11
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2021, 'AdjustedPrevAmt'] = cont_data_df['PrevAmt']*1.00

cont_data_df['ElectionTemp'] = cont_data_df['Election']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2001, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.55
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2005, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.40
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2009, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.28
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2013, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.17
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2017, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.11
cont_data_df['Election'] = cont_data_df['ElectionTemp']
cont_data_df.loc[cont_data_df['ElectionTemp'] == 2021, 'AdjustedTotalAmount'] = cont_data_df['TotalAmount']*1.00
cont_data_df
# Out:
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:844: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\ProgramData\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexing.py:965: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# Export cleaned data
cont_data_df.to_csv("./Resources/Clean_Committee_2017_Revised.csv", encoding='utf-8', index=False)

# %%
# Read the data for the next file
cont_data2_df = pd.read_csv("./Resources/Clean_Indivdual_2017.csv", low_memory=False)
cont_data2_df.head()
# Out:
#    Unnamed: 0  Election  CandidateID        CandidateName        Date  \
# 0           0      2017          326      de Blasio, Bill  2017-08-07
# 1           1      2017         2071  Malliotakis, Nicole  2017-09-20
# 2           2      2017         2051     Slattery, Collin  2017-06-01
# 3           3      2017          326      de Blasio, Bill  2017-10-23
# 4           4      2017          326      de Blasio, Bill  2016-05-08
#
#                Name ContributerType BoroughName          City State  ZipCode  \
# 0  A Hayes, Melinda      Individual    Brooklyn      Brooklyn    NY  11213.0
# 1   Aalbue, Raymond      Individual    Brooklyn      Brooklyn    NY  11209.0
# 2      Aaron, Allen      Individual      Queens  Howard Beach    NY  11414.0
# 3   Aarons, Natasha      Individual   Manhattan      New York    NY  10027.0
# 4     Ababio, Carol      Individual       Other     Riverview    FL  33579.0
#
#   ContributionState  Amount  MatchAmt  PrevAmt    PayMethod  TotalAmount
# ...

# %%
# Drop unnecessary columns
cont_data2_df = cont_data2_df.drop(['CandidateID', 'Date', 'ContributionState', 'ContributerType', 'PayMethod'], axis=1)
cont_data2_df
# Out:
#        Unnamed: 0  Election        CandidateName               Name  \
# 0               0      2017      de Blasio, Bill   A Hayes, Melinda
# 1               1      2017  Malliotakis, Nicole    Aalbue, Raymond
# 2               2      2017     Slattery, Collin       Aaron, Allen
# 3               3      2017      de Blasio, Bill    Aarons, Natasha
# 4               4      2017      de Blasio, Bill      Ababio, Carol
# ...           ...       ...                  ...                ...
# 27442       27442      2017  Malliotakis, Nicole    Zwerdling, Marc
# 27443       27443      2017  Malliotakis, Nicole    ZWERMAN, ANDREW
# 27444       27444      2017      de Blasio, Bill    Zwiebach, Peter
# 27445       27445      2017      de Blasio, Bill  Zyati, Abdessadeq
# 27446       27446      2017      de Blasio, Bill   Zygnerski, Karen
#
#       BoroughName          City State  ZipCode  Amount  MatchAmt  PrevAmt  \
# 0        Brooklyn      Brooklyn    NY  11213.0     5.0       5.0      0.0
# ...

# %%
# Regularize numerical columns
cont_data2_df['ZipCode'] = cont_data2_df['ZipCode'].dropna()
cont_data2_df['ZipCode'] = cont_data2_df['ZipCode'].round(2)
cont_data2_df['Amount'] = cont_data2_df['Amount'].round(2)
cont_data2_df['PrevAmt'] = cont_data2_df['PrevAmt'].round(2)
cont_data2_df['TotalAmount'] = cont_data2_df['TotalAmount'].round(2)
cont_data2_df
# Out:
#        Unnamed: 0  Election        CandidateName               Name  \
# 0               0      2017      de Blasio, Bill   A Hayes, Melinda
# 1               1      2017  Malliotakis, Nicole    Aalbue, Raymond
# 2               2      2017     Slattery, Collin       Aaron, Allen
# 3               3      2017      de Blasio, Bill    Aarons, Natasha
# 4               4      2017      de Blasio, Bill      Ababio, Carol
# ...           ...       ...                  ...                ...
# 27442       27442      2017  Malliotakis, Nicole    Zwerdling, Marc
# 27443       27443      2017  Malliotakis, Nicole    ZWERMAN, ANDREW
# 27444       27444      2017      de Blasio, Bill    Zwiebach, Peter
# 27445       27445      2017      de Blasio, Bill  Zyati, Abdessadeq
# 27446       27446      2017      de Blasio, Bill   Zygnerski, Karen
#
#       BoroughName          City State  ZipCode  Amount  MatchAmt  PrevAmt  \
# 0        Brooklyn      Brooklyn    NY  11213.0     5.0       5.0      0.0
# ...

# %%
# Converting dollar amounts according to inflation (figures derived from https://www.usinflationcalculator.com/)
cont_data2_df['ElectionTemp'] = cont_data2_df['Election']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2001, 'AdjustedAmount'] = cont_data2_df['Amount']*1.55
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2005, 'AdjustedAmount'] = cont_data2_df['Amount']*1.40
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2009, 'AdjustedAmount'] = cont_data2_df['Amount']*1.28
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2013, 'AdjustedAmount'] = cont_data2_df['Amount']*1.17
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2017, 'AdjustedAmount'] = cont_data2_df['Amount']*1.11
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2021, 'AdjustedAmount'] = cont_data2_df['Amount']*1.00

cont_data2_df['ElectionTemp'] = cont_data2_df['Election']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2001, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.55
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2005, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.40
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2009, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.28
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2013, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.17
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2017, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.11
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2021, 'AdjustedMatchAmt'] = cont_data2_df['MatchAmt']*1.00

cont_data2_df['ElectionTemp'] = cont_data2_df['Election']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2001, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.55
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2005, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.40
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2009, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.28
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2013, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.17
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2017, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.11
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2021, 'AdjustedPrevAmt'] = cont_data2_df['PrevAmt']*1.00

cont_data2_df['ElectionTemp'] = cont_data2_df['Election']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2001, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.55
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2005, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.40
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2009, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.28
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2013, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.17
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2017, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.11
cont_data2_df['Election'] = cont_data2_df['ElectionTemp']
cont_data2_df.loc[cont_data2_df['ElectionTemp'] == 2021, 'AdjustedTotalAmount'] = cont_data2_df['TotalAmount']*1.00
cont_data2_df
# Out:
#        Unnamed: 0  Election        CandidateName               Name  \
# 0               0      2017      de Blasio, Bill   A Hayes, Melinda
# 1               1      2017  Malliotakis, Nicole    Aalbue, Raymond
# 2               2      2017     Slattery, Collin       Aaron, Allen
# 3               3      2017      de Blasio, Bill    Aarons, Natasha
# 4               4      2017      de Blasio, Bill      Ababio, Carol
# ...           ...       ...                  ...                ...
# 27442       27442      2017  Malliotakis, Nicole    Zwerdling, Marc
# 27443       27443      2017  Malliotakis, Nicole    ZWERMAN, ANDREW
# 27444       27444      2017      de Blasio, Bill    Zwiebach, Peter
# 27445       27445      2017      de Blasio, Bill  Zyati, Abdessadeq
# 27446       27446      2017      de Blasio, Bill   Zygnerski, Karen
#
#       BoroughName          City State  ZipCode  Amount  MatchAmt  PrevAmt  \
# 0        Brooklyn      Brooklyn    NY  11213.0     5.0       5.0      0.0
# ...

# %%
# Export cleaned data
cont_data_df.to_csv("./Resources/Clean_Individual_2017_Revised.csv", encoding='utf-8', index=False)
