# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter


from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
#Import the Individual Contributions of 2017 CSV
indiv_cont_2017_df = pd.read_csv("Resources/Individual Contributions 2017 (X).csv")
indiv_cont_2017_df.head()
# Out:
#    ELECTION  OFFICECD RECIPID CANCLASS            RECIPNAME COMMITTEE  FILING  \
# 0      2017         1     326        P      de Blasio, Bill         P      10
# 1      2017         1      AU        P      Albanese, Sal F         J       6
# 2      2017         1    2071        P  Malliotakis, Nicole         H      13
# 3      2017         1    2051        P     Slattery, Collin         H       9
# 4      2017         1    1958       NP  Massey, Jr., Paul J         H       7
#
#   SCHEDULE  PAGENO  SEQUENCENO  ... INTEMPSTNM INTEMPCITY INTEMPST  INTOCCUPA  \
# 0      ABC     NaN         NaN  ...        NaN        NaN      NaN        NaN
# 1      ABC     NaN         NaN  ...        NaN        NaN      NaN        NaN
# 2      ABC     NaN         NaN  ...        NaN        NaN      NaN        NaN
# 3      ABC     NaN         NaN  ...        NaN        NaN      NaN        NaN
# 4      ABC     NaN         NaN  ...   Broadway   New York       NY  Architect
#
# ...

# %%
indiv_cont_2017_df.drop(['FILING', 'SCHEDULE', "PAGENO", 'SEQUENCENO', 'REFNO', 'REFUNDDATE','STRNO','STRNAME', 'APARTMENT',
                        'BOROUGHCD', 'EMPSTRNO','EMPSTRNAME', 'EMPCITY', 'EMPSTATE', 'PREVAMNT', 'PAY_METHOD', 'INTERMNO',
                        'INTERMNAME', 'INTERMNO', 'INTERMNAME', 'INTSTRNO', 'INTSTRNM', 'INTAPTNO', 'INTCITY', 'INTST',
                        'INTZIP', 'INTEMPNAME', 'INTEMPSTNO', 'INTEMPSTNM', 'INTEMPCITY', 'INTEMPST', 'INTOCCUPA', 'PURPOSECD',
                        'EXEMPTCD', 'ADJTYPECD', 'RR_IND', 'SEG_IND', 'INT_C_CODE'], axis = 1, inplace=True)

# %%
indiv_cont_2017_df.columns
# Out:
# Index(['ELECTION', 'OFFICECD', 'RECIPID', 'CANCLASS', 'RECIPNAME', 'COMMITTEE',
#        'DATE', 'NAME', 'C_CODE', 'CITY', 'STATE', 'ZIP', 'OCCUPATION',
#        'EMPNAME', 'AMNT', 'MATCHAMNT'],
#       dtype='object')

# %%
indiv_cont_2017_df.head(10)
# Out:
#    ELECTION  OFFICECD RECIPID CANCLASS            RECIPNAME COMMITTEE  \
# 0      2017         1     326        P      de Blasio, Bill         P
# 1      2017         1      AU        P      Albanese, Sal F         J
# 2      2017         1    2071        P  Malliotakis, Nicole         H
# 3      2017         1    2051        P     Slattery, Collin         H
# 4      2017         1    1958       NP  Massey, Jr., Paul J         H
# 5      2017         1    1958       NP  Massey, Jr., Paul J         H
# 6      2017         1    1958       NP  Massey, Jr., Paul J         H
# 7      2017         1     326        P      de Blasio, Bill         P
# 8      2017         1    1958       NP  Massey, Jr., Paul J         H
# 9      2017         1    1958       NP  Massey, Jr., Paul J         H
#
#          DATE                NAME C_CODE                CITY STATE    ZIP  \
# 0    8/7/2017    A Hayes, Melinda    IND            Brooklyn    NY  11213
# ...

# %%
# Determine the number of unique values in each column.
#  YOUR CODE GOES HERE

n = application_df.nunique(axis=0)
  
print("No.of.unique values in each column :\n",
      n)

# %%
# Look at APPLICATION_TYPE value counts for binning
#  YOUR CODE GOES HERE

application_df['APPLICATION_TYPE'].value_counts()

# %%
# Remove rows that have at least 1 null value.
# part 1
# YOUR CODE HERE
for column in crypto_df.columns:
    print (f"Column {column} has {crypto_df [column].isnull().sum()} null values")

# %%
#Drop null rows
# part 2 from above
crypto_df = crypto_df.dropna()

# %%
for column in crypto_df.columns:
    print (f"Column {column} has {crypto_df [column].isnull().sum()} null values")

# %%
# Keep the rows where coins are mined.
# YOUR CODE HERE

crypto_df = crypto_df[(crypto_df.TotalCoinsMined != 0)]
crypto_df.head()

# %%
# Create a new DataFrame that holds only the cryptocurrencies names.
crypto_name_df = crypto_df.filter(["CoinName"], axis = 1)
crypto_name_df.head(10)

# %%
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')

# Drop the null rows
df = df.dropna()

# %%
# convert interest rate to numerical
df['int_rate'] = df['int_rate'].str.replace('%', '')
df['int_rate'] = df['int_rate'].astype('float') / 100

# %%
employees.rename(columns={'age': 'User Age', 'salary': 'Salary 2018'}, inplace=True)
print(employees)
