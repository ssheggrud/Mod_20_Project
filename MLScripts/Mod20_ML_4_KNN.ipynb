# %%
# Initial imports
from path import Path
from sklearn import tree
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
import pandas as pd
import numpy as np

# %%
file = '../Resources/Clean_Committee_2013.csv'
IC_2017 = pd.read_csv(file,index_col='CandidateName')
uncleaned = pd.read_csv(file,index_col=False)
IC_2017.head()
# Out:
#                     Unnamed: 0  Election  CandidateID        Date  \
# CandidateName
# Quinn, Christine C           0      2013          204  2011-07-11
# Quinn, Christine C           1      2013          204  2013-01-10
# de Blasio, Bill              2      2013          326  2010-04-29
# de Blasio, Bill              3      2013          326  2013-09-08
# de Blasio, Bill              4      2013          326  2013-09-08
#
#                                               Name  \
# CandidateName
# Quinn, Christine C     1199 SEIU PAC - NYS PA Fund
# Quinn, Christine C     1199 SEIU PAC - NYS PA Fund
# de Blasio, Bill     1199/SEIU NYS Pol. Action Fund
# de Blasio, Bill     1199/SEIU NYS Pol. Action Fund
# de Blasio, Bill     1199/SEIU NYS Pol. Action Fund
#
#                                ContributerType BoroughName      City State  \
# CandidateName
# Quinn, Christine C  Political Action Committee   Manhattan  New York    NY
# Quinn, Christine C  Political Action Committee   Manhattan  New York    NY
# de Blasio, Bill     Political Action Committee   Manhattan  New York    NY
# de Blasio, Bill     Political Action Committee   Manhattan  New York    NY
# de Blasio, Bill     Political Action Committee   Manhattan  New York    NY
#
#                     ZipCode  ContributionState    Amount  MatchAmt  PrevAmt  \
# CandidateName
# Quinn, Christine C  10036.0                NaN   1000.00       0.0      0.0
# Quinn, Christine C  10036.0                NaN   3950.00       0.0   1000.0
# de Blasio, Bill     10036.0                NaN   4950.00       0.0      0.0
# de Blasio, Bill     10036.0                NaN  19084.25       0.0      0.0
# de Blasio, Bill     10036.0                NaN    168.31       0.0      0.0
#
#                    PayMethod  TotalAmount
# CandidateName
# Quinn, Christine C     Check      1000.00
# Quinn, Christine C     Check      4950.00
# de Blasio, Bill        Check      4950.00
# de Blasio, Bill      Unknown     19084.25
# de Blasio, Bill      Unknown       168.31

# %%
IC_2017.columns
# Out:
# Index(['Unnamed: 0', 'Election', 'CandidateID', 'Date', 'Name',
#        'ContributerType', 'BoroughName', 'City', 'State', 'ZipCode',
#        'ContributionState', 'Amount', 'MatchAmt', 'PrevAmt', 'PayMethod',
#        'TotalAmount'],
#       dtype='object')

# %%
IC_2017_df = IC_2017.drop(columns=['ContributionState','PayMethod','Name','CandidateID','Unnamed: 0','Election','BoroughName'])
IC_2017_df
# Out:
#                                 Date             ContributerType         City  \
# CandidateName
# Quinn, Christine C        2011-07-11  Political Action Committee     New York
# Quinn, Christine C        2013-01-10  Political Action Committee     New York
# de Blasio, Bill           2010-04-29  Political Action Committee     New York
# de Blasio, Bill           2013-09-08  Political Action Committee     New York
# de Blasio, Bill           2013-09-08  Political Action Committee     New York
# ...                              ...                         ...          ...
# de Blasio, Bill           2013-10-12  Political Action Committee   Washington
# de Blasio, Bill           2013-10-21  Political Action Committee   Washington
# Quinn, Christine C        2012-06-22                 Corporation     New York
# Quinn, Christine C        2012-06-22                 Corporation     New York
# Thompson, Jr., William C  2011-10-14                       Other  West Orange
#
#                          State  ZipCode    Amount  MatchAmt  PrevAmt  \
# CandidateName
# Quinn, Christine C          NY  10036.0   1000.00       0.0      0.0
# Quinn, Christine C          NY  10036.0   3950.00       0.0   1000.0
# de Blasio, Bill             NY  10036.0   4950.00       0.0      0.0
# de Blasio, Bill             NY  10036.0  19084.25       0.0      0.0
# de Blasio, Bill             NY  10036.0    168.31       0.0      0.0
# ...                        ...      ...       ...       ...      ...
# de Blasio, Bill             DC  20004.0   1000.00       0.0      0.0
# de Blasio, Bill             DC  20004.0   2000.00       0.0   1000.0
# Quinn, Christine C          NY  10011.0   1000.00       0.0      0.0
# Quinn, Christine C          NY  10011.0  -1000.00       0.0      0.0
# Thompson, Jr., William C    NJ   7052.0     50.00       0.0      0.0
#
#                           TotalAmount
# CandidateName
# Quinn, Christine C            1000.00
# Quinn, Christine C            4950.00
# de Blasio, Bill               4950.00
# de Blasio, Bill              19084.25
# de Blasio, Bill                168.31
# ...                               ...
# de Blasio, Bill               1000.00
# de Blasio, Bill               3000.00
# Quinn, Christine C            1000.00
# Quinn, Christine C           -1000.00
# Thompson, Jr., William C        50.00
#
# [732 rows x 9 columns]

# %%
IC_2017_df['ZipCode'] = IC_2017_df['ZipCode'].apply(str)

# %%
outcome = []
for i in uncleaned['CandidateName']:
    if i == 'de Blasio, Bill':
        outcome.append('W')
    else:
        outcome.append('L')

IC_2017_df['Outcome'] = outcome
IC_2017_df.head()
# Out:
#                           Date             ContributerType      City State  \
# CandidateName
# Quinn, Christine C  2011-07-11  Political Action Committee  New York    NY
# Quinn, Christine C  2013-01-10  Political Action Committee  New York    NY
# de Blasio, Bill     2010-04-29  Political Action Committee  New York    NY
# de Blasio, Bill     2013-09-08  Political Action Committee  New York    NY
# de Blasio, Bill     2013-09-08  Political Action Committee  New York    NY
#
#                     ZipCode    Amount  MatchAmt  PrevAmt  TotalAmount Outcome
# CandidateName
# Quinn, Christine C  10036.0   1000.00       0.0      0.0      1000.00       L
# Quinn, Christine C  10036.0   3950.00       0.0   1000.0      4950.00       L
# de Blasio, Bill     10036.0   4950.00       0.0      0.0      4950.00       W
# de Blasio, Bill     10036.0  19084.25       0.0      0.0     19084.25       W
# de Blasio, Bill     10036.0    168.31       0.0      0.0       168.31       W

# %%
IC_2017_df = IC_2017_df.dropna()
IC_2017_df.isnull().sum()
# Out:
# Date               0
# ContributerType    0
# City               0
# State              0
# ZipCode            0
# Amount             0
# MatchAmt           0
# PrevAmt            0
# TotalAmount        0
# Outcome            0
# dtype: int64

# %%
IC_2017_df.dtypes
# Out:
# Date                object
# ContributerType     object
# City                object
# State               object
# ZipCode             object
# Amount             float64
# MatchAmt           float64
# PrevAmt            float64
# TotalAmount        float64
# Outcome             object
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.feature_selection import SelectKBest, chi2
le = LabelEncoder()
# IC_2017_df['CandidateName']= le.fit_transform(IC_2017_df['CandidateName'])
IC_2017_df['Date'] = le.fit_transform(IC_2017_df['Date'])
IC_2017_df['ContributerType'] = le.fit_transform(IC_2017_df['ContributerType'])
IC_2017_df['City'] = le.fit_transform(IC_2017_df['City'])
IC_2017_df['Amount'] = le.fit_transform(IC_2017_df['Amount'])
IC_2017_df['State'] = le.fit_transform(IC_2017_df['State'])
IC_2017_df['ZipCode'] = le.fit_transform(IC_2017_df['ZipCode'])
IC_2017_df['MatchAmt'] = le.fit_transform(IC_2017_df['MatchAmt'])
IC_2017_df['PrevAmt'] = le.fit_transform(IC_2017_df['PrevAmt'])
IC_2017_df['TotalAmount'] = le.fit_transform(IC_2017_df['TotalAmount'])
IC_2017_df['Outcome'] = le.fit_transform(IC_2017_df['Outcome'])
IC_2017_df.head()
# Out:
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /Users/Abir/.local/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
#                     Date  ContributerType  City  State  ZipCode  Amount  \
# CandidateName
# Quinn, Christine C   136                7    54     18       20      51
# Quinn, Christine C   210                7    54     18       20      77
# de Blasio, Bill       58                7    54     18       20      84
# de Blasio, Bill      262                7    54     18       20      86
# de Blasio, Bill      262                7    54     18       20      32
#
#                     MatchAmt  PrevAmt  TotalAmount  Outcome
# CandidateName
# Quinn, Christine C         0        0           51        0
# Quinn, Christine C         0        8           99        0
# de Blasio, Bill            0        0           99        1
# de Blasio, Bill            0        0          117        1
# de Blasio, Bill            0        0           32        1

# %%
# separate train features and label
y = IC_2017_df["Outcome"]
X = IC_2017_df.drop(labels=["Outcome"], axis=1)
# split dataset into train and test data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)
# train and test knn model
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)
print("Testing Accuracy is: ", knn.score(X_test, y_test)*100, "%")
# Out:
# Testing Accuracy is:  68.02721088435374 %

# %%
features = list(IC_2017_df.columns)

# %%
from imblearn.metrics import classification_report_imbalanced
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                    pre       rec       spe        f1       geo       iba       sup
#
#           0       0.69      0.78      0.55      0.73      0.65      0.44        83
#           1       0.66      0.55      0.78      0.60      0.65      0.42        64
#
# avg / total       0.68      0.68      0.65      0.68      0.65      0.43       147

# %%
# Display the confusion matrix
# YOUR CODE HERE
# Display the confusion matrix
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test, y_pred)
# Out:
# array([[65, 18],
#        [29, 35]])
